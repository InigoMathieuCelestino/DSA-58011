# %% [markdown]
# <a href="https://colab.research.google.com/github/InigoMathieuCelestino/DSA-58011/blob/main/LongExamination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
  def __init__(self, name): 
    self.data = name
    self.next = None  

class LinkedList:
  def __init__(self):
    self.head = None 
  def printList(self):
    name = self.head
    while(name):
      print(name.data)
      name = name.next

llist = LinkedList()
llist.head = Node('o')
second = Node('g')
third = Node('i')
fourth = Node('ñ')
fifth = Node('I')
sixth = Node(' ')
seventh = Node('u')
eight = Node('e')
nineth = Node('i')
tenth = Node('h')
eleventh = Node('t')
twelveth = Node('a')
thirteenth = Node('M')
fourteenth = Node(' ')
fifthteenth = Node('D.')
sixteenth = Node(' ')
seventeenth = Node('o')
eighteenth = Node('n')
nineteenth = Node('i')
twentieth = Node('t')
twentyoneth = Node('s')
twentytwoth = Node('e')
twentythree = Node('l')
twentyfour = Node('e')
twentyfive = Node('C')


llist.head.next = second
second.next = third
third.next = fourth
fourth.next = fifth
fifth.next = sixth
sixth.next = seventh
seventh.next = eight
eight.next = nineth
nineth.next = tenth
tenth.next = eleventh
eleventh.next = twelveth
twelveth.next = thirteenth
thirteenth.next = fourteenth
fourteenth.next = fifthteenth
fifthteenth.next = sixteenth
sixteenth.next = seventeenth
seventeenth.next = eighteenth
eighteenth.next = nineteenth
nineteenth.next = twentieth
twentieth.next = twentyoneth
twentyoneth.next = twentytwoth
twentytwoth.next = twentythree
twentythree.next = twentyfour
twentyfour.next = twentyfive

llist.printList()
# Out:
# o
# g
# i
# ñ
# I
#
# u
# e
# i
# h
# t
# a
# M
#
# D.
#
# o
# n
# i
# t
# s
# e
# l
# e
# C

# %%
class Node:
  def __init__(self, name): 
    self.data = name
    self.next = None  

class LinkedList:
  def __init__(self):
    self.head = None 
  def printList(self):
    name = self.head
    while(name):
      print(name.data)
      name = name.next

llist = LinkedList()
llist.head = Node('o')
second = Node('n')
third = Node('i')
fourth = Node('t')
fifth = Node('s')
sixth = Node('e')
seventh = Node('l')
eight = Node('e')
nineth = Node('C')
tenth = Node(' ')
eleventh = Node('D.')
twelveth = Node(' ')
thirteenth = Node('u')
fourteenth = Node('e')
fifthteenth = Node('i')
sixteenth = Node('h')
seventeenth = Node('t')
eighteenth = Node('a')
nineteenth = Node('M')
twentieth = Node(' ')
twentyoneth = Node('o')
twentytwoth = Node('g')
twentythree = Node('i')
twentyfour = Node('ñ')
twentyfive = Node('I')


llist.head.next = second
second.next = third
third.next = fourth
fourth.next = fifth
fifth.next = sixth
sixth.next = seventh
seventh.next = eight
eight.next = nineth
nineth.next = tenth
tenth.next = eleventh
eleventh.next = twelveth
twelveth.next = thirteenth
thirteenth.next = fourteenth
fourteenth.next = fifthteenth
fifthteenth.next = sixteenth
sixteenth.next = seventeenth
seventeenth.next = eighteenth
eighteenth.next = nineteenth
nineteenth.next = twentieth
twentieth.next = twentyoneth
twentyoneth.next = twentytwoth
twentytwoth.next = twentythree
twentythree.next = twentyfour
twentyfour.next = twentyfive

llist.printList()
# Out:
# o
# n
# i
# t
# s
# e
# l
# e
# C
#
# D.
#
# u
# e
# i
# h
# t
# a
# M
#
# o
# g
# i
# ñ
# I

# %%
class Node:
  def __init__(self, name): 
    self.data = name
    self.next = None  

class LinkedList:
  def __init__(self):
    self.head = None 
  def printList(self):
    name = self.head
    while(name):
      print(name.data)
      name = name.next

llist = LinkedList()
llist.head = Node('I')
second = Node('ñ')
third = Node('i')
fourth = Node('g')
fifth = Node('o')
sixth = Node(' ')
seventh = Node('M')
eight = Node('a')
nineth = Node('t')
tenth = Node('h')
eleventh = Node('i')
twelveth = Node('e')
thirteenth = Node('u')
fourteenth = Node(' ')
fifthteenth = Node('D.')
sixteenth = Node(' ')
seventeenth = Node('C')
eighteenth = Node('e')
nineteenth = Node('l')
twentieth = Node('e')
twentyoneth = Node('s')
twentytwoth = Node('t')
twentythree = Node('i')
twentyfour = Node('n')
twentyfive = Node('o')


llist.head.next = second
second.next = third
third.next = fourth
fourth.next = fifth
fifth.next = sixth
sixth.next = seventh
seventh.next = eight
eight.next = nineth
nineth.next = tenth
tenth.next = eleventh
eleventh.next = twelveth
twelveth.next = thirteenth
thirteenth.next = fourteenth
fourteenth.next = fifthteenth
fifthteenth.next = sixteenth
sixteenth.next = seventeenth
seventeenth.next = eighteenth
eighteenth.next = nineteenth
nineteenth.next = twentieth
twentieth.next = twentyoneth
twentyoneth.next = twentytwoth
twentytwoth.next = twentythree
twentythree.next = twentyfour
twentyfour.next = twentyfive

llist.printList()
# Out:
# I
# ñ
# i
# g
# o
#
# M
# a
# t
# h
# i
# e
# u
#
# D.
#
# C
# e
# l
# e
# s
# t
# i
# n
# o
